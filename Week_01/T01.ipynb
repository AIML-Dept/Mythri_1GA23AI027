# %%
# Objective-To install Qiskit and verify that it is working correctly.
import qiskit
print("Qiskit Version:")
print(qiskit.__version__)
# Out:
# Qiskit Version:
# 1.3.2

# %%
# %matplotlib inline

# %%
# Tutorial Number : 01
# Date            : 23-07-2026
# Objective       : Create a 1-qubit circuit, apply a Hadamard
#                   gate, measure it, execute 1024 shots on
#                   the simulator, and plot the histogram.
# ------------------------------------------------------------

# Import required libraries
from qiskit import QuantumCircuit, transpile
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram
import matplotlib.pyplot as plt

# Step 1: Create a quantum circuit with 1 qubit and 1 classical bit
qc = QuantumCircuit(1, 1)

# Step 2: Apply Hadamard gate to create superposition
qc.h(0)

# Step 3: Measure the qubit
qc.measure(0, 0)

# Display the circuit
print("Quantum Circuit:")
print(qc)

# Step 4: Create the simulator
simulator = AerSimulator()

# Step 5: Compile the circuit
compiled_circuit = transpile(qc, simulator)

# Step 6: Execute the circuit with 1024 shots
job = simulator.run(compiled_circuit, shots=1024)

# Step 7: Get the results
result = job.result()
counts = result.get_counts()

# Step 8: Print the measurement counts
print("\nMeasurement Results:")
print(counts)

# Step 9: Plot the histogram
plot_histogram(counts)
plt.show()
# Out:
# Quantum Circuit:
#      ┌───┐┌─┐
#   q: ┤ H ├┤M├
#      └───┘└╥┘
# c: 1/══════╩═
#            0
#
# Measurement Results:
# {'1': 504, '0': 520}
